# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_profiling as pp
from summarytools import dfSummary
import sklearn
# Out:
# C:\Users\rodge\AppData\Local\Temp\ipykernel_21356\179479608.py:4: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling as pp

# %%
df =  pd.read_csv(r"C:\Users\rodge\Downloads\tweets.csv\tweets.csv")

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_cdb5d thead>tr>th {
#   text-align: left;
# }
# #T_cdb5d_row0_col0, #T_cdb5d_row1_col0, #T_cdb5d_row2_col0, #T_cdb5d_row3_col0, #T_cdb5d_row4_col0, #T_cdb5d_row5_col0, #T_cdb5d_row6_col0, #T_cdb5d_row7_col0, #T_cdb5d_row8_col0, #T_cdb5d_row9_col0, #T_cdb5d_row10_col0, #T_cdb5d_row11_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_cdb5d_row0_col1, #T_cdb5d_row1_col1, #T_cdb5d_row2_col1, #T_cdb5d_row3_col1, #T_cdb5d_row4_col1, #T_cdb5d_row5_col1, #T_cdb5d_row6_col1, #T_cdb5d_row7_col1, #T_cdb5d_row8_col1, #T_cdb5d_row9_col1, #T_cdb5d_row10_col1, #T_cdb5d_row11_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# ...

# %%
df.head()
# Out:
#                   user_name                   user_location  \
# 0           BestCompaniesAZ                        Arizona
# 1           BestCompaniesAZ                        Arizona
# 2                   CHILUDO                             NaN
# 3                      ANIL  New Delhi, India, From Bihar.
# 4  🇺🇸 My Head’s Exploding 🤯      leswarden@mastodon.world 👈
#
#                                     user_description  \
# 0  We validate and elevate the best companies to ...
# 1  We validate and elevate the best companies to ...
# 2                           AMC APE MAKING APE MOVES
# 3  New Delhi. Above politicos. An economist and I...
# 4  A Proud Believer in Democracy, Our Constitutio...
#
#                 user_created  user_followers  user_friends user_favourites  \
# 0  2009-01-11 16:28:33+00:00          2836.0        2469.0             870
# 1  2009-01-11 16:28:33+00:00          2835.0        2469.0             870
# ...

# %%
df.user_name.nunique(), df.shape
# Out:
# (17340, (25491, 12))

# %%
df.dtypes
# Out:
# user_name            object
# user_location        object
# user_description     object
# user_created         object
# user_followers      float64
# user_friends        float64
# user_favourites      object
# user_verified        object
# date                 object
# text                 object
# hashtags             object
# source               object
# dtype: object

# %%
df.isnull().sum(), df.isnull().mean()
# Out:
# (user_name              2
#  user_location       7375
#  user_description    2695
#  user_created           1
#  user_followers         1
#  user_friends           1
#  user_favourites        1
#  user_verified          1
#  date                   1
#  text                   1
#  hashtags            8339
#  source                 2
#  dtype: int64,
#  user_name           0.000078
#  user_location       0.289318
#  user_description    0.105724
#  user_created        0.000039
#  user_followers      0.000039
#  user_friends        0.000039
#  user_favourites     0.000039
#  user_verified       0.000039
#  date                0.000039
#  text                0.000039
#  hashtags            0.327135
#  source              0.000078
#  dtype: float64)

# %%
df.head(3)
# Out:
#          user_name user_location  \
# 0  BestCompaniesAZ      Arizona
# 1  BestCompaniesAZ      Arizona
# 2          CHILUDO           NaN
#
#                                     user_description  \
# 0  We validate and elevate the best companies to ...
# 1  We validate and elevate the best companies to ...
# 2                           AMC APE MAKING APE MOVES
#
#                 user_created  user_followers  user_friends user_favourites  \
# 0  2009-01-11 16:28:33+00:00          2836.0        2469.0             870
# 1  2009-01-11 16:28:33+00:00          2835.0        2469.0             870
# 2  2022-03-27 17:10:55+00:00            19.0          32.0               4
#
#   user_verified                       date  \
# 0         False  2022-12-20 18:00:48+00:00
# 1         False  2022-12-20 18:00:48+00:00
# 2         False  2022-12-18 00:21:03+00:00
#
#                                                 text  \
# 0  Apply today!:\nhttps://t.co/eCRVPFByiy\n\n#app...
# ...

# %%
df.tail(3)
# Out:
#                     user_name        user_location  \
# 25488          Amsterdammer 🚜    Zandvoort, Mokum
# 25489  Mauricio Tremea Zaquia  Amsterdam, Pays-Bas
# 25490               Zbyszek K                  NaN
#
#                                         user_description  \
# 25488  AJAX, Mokum, Buitenlandse politiek. Vanilla ni...
# 25489  Silly retweets, mostly. Mobile development lea...
# 25490                                                NaN
#
#                     user_created  user_followers  user_friends  \
# 25488  2019-04-22 08:28:36+00:00           318.0         476.0
# 25489  2013-10-19 00:16:47+00:00           252.0         447.0
# 25490  2022-09-06 03:12:14+00:00             0.0           1.0
#
#       user_favourites user_verified                       date  \
# 25488           32986         False  2022-09-06 05:24:41+00:00
# 25489            2495         False  2022-09-06 04:27:23+00:00
# 25490               3         False  2022-09-06 03:34:14+00:00
#
# ...
